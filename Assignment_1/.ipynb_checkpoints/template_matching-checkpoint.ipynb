# %%
# Student Name: Nayem Alam
# Student ID:   260743549
# Assignment    1

import numpy as np
import cv2
import matplotlib.pyplot as plt
import skimage
from skimage import data, io, filters
import math

# --- Part 3: Q. 1 ---

# reference image
park = "./where_is_waldo.jpg"
template1 = "./template1.png"

park_img = cv2.imread(park)
temp1 = cv2.imread(template1)

park_img_grey = cv2.cvtColor(park_img, cv2.COLOR_BGR2RGB)
temp1 = cv2.cvtColor(temp1, cv2.COLOR_BGR2RGB)

img_disp = park_img_grey.copy()

wt, ht = temp1.shape[0:2]

# create copy for res
img = img_disp.copy()

# apply template matching: cv2.matchTemplate(ref, temp, SSD)
res = cv2.matchTemplate(img,temp1,cv2.TM_SQDIFF)
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

# where ssd = minimum
top_left = min_loc
bottom_right = (top_left[0] + wt, top_left[1] + ht)

# cv2.rectangle(img, pt1, pt2, color[, thickness[, lineType[, shift]]]) → None
cv2.rectangle(img,top_left, bottom_right, (0,175,8), 10)

plt.figure(figsize=(20,20))
plt.subplot(131), plt.imshow(img_disp)
plt.title("Input Image"), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(temp)
plt.title("Template Image"), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(img)
plt.title("Detected Point (green box)"), plt.xticks([]), plt.yticks([])
plt.show()

print("(x,y) coordinates of where waldo is: ",min_loc)

# --- Part 3: Q. 1 ---
# Out:
# (x,y) coordinates of where waldo is:  (1258, 74)

# %%
# --- Part 3: Q. 2 ---

# loading template 2
template2 = "./template2.png"
temp2 = cv2.imread(template2)
temp2 = cv2.cvtColor(temp2, cv2.COLOR_BGR2RGB)

wt, ht = temp2.shape[0:2]

# create copy for res
img2 = img_disp.copy()

# apply template matching: cv2.matchTemplate(ref, temp, SSD)
res1 = cv2.matchTemplate(img2,temp2,cv2.TM_SQDIFF)
min_val1, max_val1, min_loc1, max_loc1 = cv2.minMaxLoc(res1)

# where ssd = minimum
top_left1 = min_loc1
bottom_right1 = (top_left1[0] + wt, top_left1[1] + ht)

# cv2.rectangle(img, pt1, pt2, color[, thickness[, lineType[, shift]]]) → None
cv2.rectangle(img2,top_left1, bottom_right1, (0,175,8), 10)

plt.figure(figsize=(20,20))
plt.subplot(131), plt.imshow(img_disp)
plt.title("Input Image"), plt.xticks([]), plt.yticks([])

plt.subplot(132), plt.imshow(temp2)
plt.title("Template Image (Noisy)"), plt.xticks([]), plt.yticks([])

plt.subplot(133), plt.imshow(img2)
plt.title("Detected Point (green box)"), plt.xticks([]), plt.yticks([])
plt.show()

print("(x,y) coordinates of where waldo is: ",min_loc1)

# --- END of Part 3: Q. 2 ---
# Out:
# (x,y) coordinates of where waldo is:  (1258, 74)
